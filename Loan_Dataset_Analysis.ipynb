# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshBrownsVI/Loan-Data-Analysis/blob/main/Loan_Dataset_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install category_encoders

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import pandas as pd
from category_encoders import TargetEncoder
sns.set(rc={'figure.figsize':(15, 10)})
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, classification_report
from sklearn import preprocessing
from sklearn import tree
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report, confusion_matrix

# %%
#read in the dataset and print out the first 5 entries
df = pd.read_csv('loan_data.csv')
df.head()
# Out:
#    credit.policy             purpose  ...  pub.rec  not.fully.paid
# 0              1  debt_consolidation  ...        0               0
# 1              1         credit_card  ...        0               0
# 2              1  debt_consolidation  ...        0               0
# 3              1  debt_consolidation  ...        0               0
# 4              1         credit_card  ...        0               0
#
# [5 rows x 14 columns]

# %%
df
# Out:
#       credit.policy             purpose  ...  pub.rec  not.fully.paid
# 0                 1  debt_consolidation  ...        0               0
# 1                 1         credit_card  ...        0               0
# 2                 1  debt_consolidation  ...        0               0
# 3                 1  debt_consolidation  ...        0               0
# 4                 1         credit_card  ...        0               0
# ...             ...                 ...  ...      ...             ...
# 9573              0           all_other  ...        0               1
# 9574              0           all_other  ...        0               1
# 9575              0  debt_consolidation  ...        0               1
# 9576              0    home_improvement  ...        0               1
# 9577              0  debt_consolidation  ...        0               1
#
# [9578 rows x 14 columns]

# %%
df.describe(include = 'all')
# Out:
#         credit.policy             purpose  ...      pub.rec  not.fully.paid
# count     9578.000000                9578  ...  9578.000000     9578.000000
# unique            NaN                   7  ...          NaN             NaN
# top               NaN  debt_consolidation  ...          NaN             NaN
# freq              NaN                3957  ...          NaN             NaN
# mean         0.804970                 NaN  ...     0.062122        0.160054
# std          0.396245                 NaN  ...     0.262126        0.366676
# min          0.000000                 NaN  ...     0.000000        0.000000
# 25%          1.000000                 NaN  ...     0.000000        0.000000
# 50%          1.000000                 NaN  ...     0.000000        0.000000
# 75%          1.000000                 NaN  ...     0.000000        0.000000
# max          1.000000                 NaN  ...     5.000000        1.000000
#
# [11 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
# checking the target columns unique values
df['not.fully.paid'].unique()
sns.countplot(x="purpose", hue='not.fully.paid', data=df, palette = "Set1")

# %%
#printing out a heatmap to check null values
sns.heatmap(df.corr())

# %%
#check null values
df.isnull().sum()
# Out:
# credit.policy        0
# purpose              0
# int.rate             0
# installment          0
# log.annual.inc       0
# dti                  0
# fico                 0
# days.with.cr.line    0
# revol.bal            0
# revol.util           0
# inq.last.6mths       0
# delinq.2yrs          0
# pub.rec              0
# not.fully.paid       0
# dtype: int64

# %%
# features are replaced with a blend of posterior probability of the target given particular categorical value 
# and the prior probability of the target over all the training data.
#Using target encoder to convert the name values to the probability of the outcome in the dataset
df['purpose'].unique
encoder = TargetEncoder()
df['purpose'] = encoder.fit_transform(df['purpose'], df['not.fully.paid'])
df.head()
# Out:
#    credit.policy   purpose  int.rate  ...  delinq.2yrs  pub.rec  not.fully.paid
# 0              1  0.152388    0.1189  ...            0        0               0
# 1              1  0.115689    0.1071  ...            0        0               0
# 2              1  0.152388    0.1357  ...            0        0               0
# 3              1  0.152388    0.1008  ...            0        0               0
# 4              1  0.115689    0.1426  ...            1        0               0
#
# [5 rows x 14 columns]

# %%
# Last column is the target column, so taking last column as target column
x = df.iloc[:,:-1]
y = df.iloc[:,-1]
# Scaling the features by using min max scaling
minmax_scale = MinMaxScaler().fit(x.iloc[:,:])
x.iloc[:,:] = minmax_scale.transform(x.iloc[:,:])
x.iloc[:,:].head()
# Out:
#    credit.policy   purpose  int.rate  ...  inq.last.6mths  delinq.2yrs  pub.rec
# 0            1.0  0.242912  0.376598  ...        0.000000     0.000000      0.0
# 1            1.0  0.021487  0.301151  ...        0.000000     0.000000      0.0
# 2            1.0  0.242912  0.484015  ...        0.030303     0.000000      0.0
# 3            1.0  0.242912  0.260870  ...        0.030303     0.000000      0.0
# 4            1.0  0.021487  0.528133  ...        0.000000     0.076923      0.0
#
# [5 rows x 13 columns]

# %%
#Q-4: Perform stratified splitting of train and test data.
#x, y = np.arange(10).reshape((5, 2)), range(5)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.33)

# %%
#Q-5: Build a classifier model using Random Forest algorithm and plot the  same.
#Setting test data for the possible decision trees and creating a random forest classifier based on each tree
n_estimators = [100, 500, 800]
max_depth = [1, 3, 5, 10]
class_weights = ['balanced', None]
best_f1 = 0

for est in n_estimators:
    for depth in max_depth:
        for wgt in class_weights:
            print(est, depth, wgt)
            clf = RandomForestClassifier(n_estimators=est, max_depth=depth, oob_score=True, class_weight=wgt)
            clf.fit(x_train, y_train)
            f1 = f1_score(y_train, np.argmax(clf.oob_decision_function_ , 1))
            if f1 > best_f1:
                best_f1 = f1
                best_params = (est, depth, wgt)
# Out:
# 100 1 balanced
# 100 1 None
# 100 3 balanced
# 100 3 None
# 100 5 balanced
# 100 5 None
# 100 10 balanced
# 100 10 None
# 500 1 balanced
# 500 1 None
# 500 3 balanced
# 500 3 None
# 500 5 balanced
# 500 5 None
# 500 10 balanced
# 500 10 None
# 800 1 balanced
# 800 1 None
# 800 3 balanced
# 800 3 None
# 800 5 balanced
# 800 5 None
# 800 10 balanced
# 800 10 None

# %%
#Q-6: Print confusion matrix and classification report.

clf = RandomForestClassifier(n_estimators=best_params[0], max_depth=best_params[1], class_weight=best_params[2])
clf.fit(x_train, y_train)
test_predictions = clf.predict(x_test)
print("Confusion Matrix: ")
print(confusion_matrix(y_test, test_predictions))
print("Test Classification Report:")
print(classification_report(y_test, test_predictions))
# Out:
# Confusion Matrix:
# [[1874  785]
#  [ 237  265]]
# Test Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.70      0.79      2659
#            1       0.25      0.53      0.34       502
#
#     accuracy                           0.68      3161
#    macro avg       0.57      0.62      0.56      3161
# weighted avg       0.79      0.68      0.72      3161

# %%
#Q-7: Find out the stratified cross validation accuracy.
#Using Stratified KFold Method
scores = cross_val_score(clf, x, y, cv=15)
print(scores)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# [0.79499218 0.78716745 0.76838811 0.70892019 0.70422535 0.76056338
#  0.76525822 0.74804382 0.7539185  0.79623824 0.73197492 0.74137931
#  0.51880878 0.18652038 0.18965517]
# Accuracy: 0.66 (+/- 0.39)
